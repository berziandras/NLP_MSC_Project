# %%
from transformers import pipeline

# %%
# tokenizer = AutoTokenizer.from_pretrained("vagrawal787/bert-finetuned-lyrics-genres-v2")
# model = AutoModelForSequenceClassification.from_pretrained("vagrawal787/bert-finetuned-lyrics-genres-v2")

# %%
classifier = pipeline("text-classification", model="vagrawal787/bert-finetuned-lyrics-genres-v2")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\berzi\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File c:\Users\berzi\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\import_utils.py:1472, in _LazyModule._get_module(self, module_name)
#    1471 try:
# -> 1472     return importlib.import_module("." + module_name, self.__name__)
#    1473 except Exception as e:
#
# ...

# %%
result = classifier("When I'm away from you, I'm happier than ever Wish I could explain it better I wish it wasn't true")

print(result)

# %%
df = pd.read_csv("C:/data/processed_spotify_millsongdata.csv")

# %%
sentences = ["This is an example sentence"]


embeddings = model.encode(sentences)
print(embeddings)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 4
#       1 sentences = ["This is an example sentence"]
# ----> 4 embeddings = model.encode(sentences)
#       5 print(embeddings)
#
# File c:\Users\berzi\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1614, in Module.__getattr__(self, name)
#    1612     if name in modules:
#    1613         return modules[name]
# -> 1614 raise AttributeError("'{}' object has no attribute '{}'".format(
#    1615     type(self).__name__, name))
#
# AttributeError: 'BertForSequenceClassification' object has no attribute 'encode'

# %%
for i in range(100):
    query_embedding = model.encode(df['cleaned_text'][0])
    passage_embedding = model.encode([df['cleaned_text'][0],
                                    df['cleaned_text'][i]])

    sim = util.dot_score(query_embedding, passage_embedding)[0]
    print(i, "Similarity:", sim[1].item())
# Out:
# 0 Similarity: 1.0
# 1 Similarity: 0.27078187465667725
# 2 Similarity: 0.1858198046684265
# 3 Similarity: 0.1328374147415161
# 4 Similarity: 0.102468341588974
# 5 Similarity: 0.029360096901655197
# 6 Similarity: 0.13929694890975952
# 7 Similarity: 0.11327213048934937
# 8 Similarity: 0.44349753856658936
# 9 Similarity: 0.16374847292900085
# 10 Similarity: 0.2488551288843155
# 11 Similarity: 0.3453655242919922
# 12 Similarity: 0.12902924418449402
# 13 Similarity: 0.3147697150707245
# 14 Similarity: 0.14255523681640625
# 15 Similarity: 0.19743940234184265
# 16 Similarity: 0.30820202827453613
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 3
#       1 for i in range(100):
#       2     query_embedding = model.encode(df['cleaned_text'][0])
# ----> 3     passage_embedding = model.encode([df['cleaned_text'][0],
# ...

# %% [markdown]
# Ez lényegében a cos similarity
